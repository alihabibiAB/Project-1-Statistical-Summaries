# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# After several years of releasing new format of SAT, we are interested to track participation rate of test takers statewide. We collected SAT and ACT scores for three years (2017-2019). To have any suggestion for targeting any state, we analyse these data sets for ACT and SAT. Here are the steps required to analyse SAT and ACT results.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
df_sat_2017=pd.read_csv("data/sat_2017.csv")
df_sat_2018=pd.read_csv("data/sat_2018.csv")
df_sat_2019=pd.read_csv("data/sat_2019.csv",encoding='latin1')

df_act_2017=pd.read_csv("data/act_2017.csv")
df_act_2018=pd.read_csv("data/act_2018.csv")
df_act_2019=pd.read_csv("data/act_2019.csv")

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
df_sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
df_sat_2018.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            6%                                 595
# 1                Alaska           43%                                 562
# 2               Arizona           29%                                 577
# 3              Arkansas            5%                                 592
# 4            California           60%                                 540
# 5              Colorado          100%                                 519
# 6           Connecticut          100%                                 535
# 7              Delaware          100%                                 505
# 8  District of Columbia           92%                                 497
# 9               Florida           56%                                 550
#
#    Math  Total
# 0   571   1166
# 1   544   1106
# 2   572   1149
# 3   576   1169
# 4   536   1076
# 5   506   1025
# 6   519   1053
# 7   492    998
# ...

# %%
df_sat_2019.head(10)
# Out:
#                   State Participation Rate  EBRW  Math  Total
# 0               Alabama                 7%   583   560   1143
# 1                Alaska                41%   556   541   1097
# 2               Arizona                31%   569   565   1134
# 3              Arkansas                 6%   582   559   1141
# 4            California                63%   534   531   1065
# 5              Colorado               100%   518   506   1024
# 6           Connecticut               100%   529   516   1046
# 7              Delaware               100%   499   486    985
# 8  District of Columbia                94%   495   480    975
# 9               Florida               100%   516   483    999

# %%
df_act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
df_act_2018.head(10)
# Out:
#                   State Participation  Composite
# 0               Alabama          100%       19.1
# 1                Alaska           33%       20.8
# 2               Arizona           66%       19.2
# 3              Arkansas          100%       19.4
# 4            California           27%       22.7
# 5              Colorado           30%       23.9
# 6           Connecticut           26%       25.6
# 7              Delaware           17%       23.8
# 8  District of columbia           32%       23.6
# 9               Florida           66%       19.9

# %%
df_act_2019.head(10)
# Out:
#                   State Participation  Composite
# 0               Alabama          100%       18.9
# 1                Alaska           38%       20.1
# 2               Arizona           73%       19.0
# 3              Arkansas          100%       19.3
# 4            California           23%       22.6
# 5              Colorado           27%       23.8
# 6           Connecticut           22%       25.5
# 7              Delaware           13%       24.1
# 8  District of Columbia           32%       23.5
# 9               Florida           54%       20.1

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
# SAT dataframes have the same number of columns but name of a header is slightly different.
# ACT_2017 is the most comprehensive dtaframe among ACT dtaframes. 4 columns (English,Math,Reading,Science) are missing in ACT_2018 and ACT_2019 dtaframes.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer:
#
# SAT data frames look complete but ACT dataframes are not complete for 2018 and 2019.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
# participation_rate (0-100), evidence-based_reading_and_writing (200-800), math_SAT (200-800), total_score_SAT (400-1600), Composite_ACT (1-36).

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
df_sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
df_sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
df_sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
df_act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
df_act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
df_act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
df_sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
df_sat_2018.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
df_sat_2019.describe()
# Out:
#              EBRW        Math        Total
# count   53.000000   53.000000    53.000000
# mean   558.000000  548.471698  1106.528302
# std     47.554422   53.785044   100.994784
# min    483.000000  445.000000   935.000000
# 25%    518.000000  506.000000  1024.000000
# 50%    550.000000  545.000000  1097.000000
# 75%    610.000000  596.000000  1200.000000
# max    636.000000  648.000000  1284.000000

# %%
df_act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
df_act_2018.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000

# %%
df_act_2019.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.450000
# std     2.175487
# min    17.900000
# 25%    19.800000
# 50%    20.950000
# 75%    23.650000
# max    25.500000

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
#
# Define a function that will allow you to convert participation rates to an appropriate numeric type. Use map or apply to change these columns in each dataframe.

# %%
def object_numeric(df):
    if "%" in df:
        df=df.replace("%"," ")
    elif "Ñ" in df:
        df=np.nan
    return pd.to_numeric(df)

# %%
df_sat_2017['Participation']=df_sat_2017['Participation'].apply(object_numeric)

# %%
df_sat_2018['Participation']=df_sat_2018['Participation'].apply(object_numeric)

# %%
df_sat_2019['Participation Rate']=df_sat_2019['Participation Rate'].apply(object_numeric)

# %%
df_act_2017['Participation']=df_act_2017['Participation'].apply(object_numeric)

# %%
df_act_2018['Participation']=df_act_2018['Participation'].apply(object_numeric)

# %%
df_act_2019['Participation']=df_act_2019['Participation'].apply(object_numeric)

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
df_act_2017['Composite']=df_act_2017['Composite'].str.replace('x',' ')
df_act_2017['Composite']=pd.to_numeric(df_act_2017['Composite'])

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
df_sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     int64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 2.1+ KB

# %%
df_sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     int64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 2.1+ KB

# %%
df_sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  51 non-null     float64
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.2+ KB

# %%
df_act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     int64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.0+ KB

# %%
df_act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     int64
#  2   Composite      52 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.3+ KB

# %%
df_act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     int64
#  2   Composite      52 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
def df_columns_sat(df,yr):
    df.columns=df.columns.str.lower().str.replace(" ","_")
    df['state']=df['state'].str.lower()
    new_column_sat_dict={'participation':"participation_rate_sat_"+str(yr),
                         'participation_rate':'participation_rate_sat_'+str(yr),
                         'evidence-based_reading_and_writing':'evidence-based_reading_and_writing_'+str(yr),
                         'math':'math_'+str(yr),
                         'ebrw' :'evidence-based_reading_and_writing_'+str(yr),
                         'total':'total_score_'+str(yr)}
    return df.rename(columns=new_column_sat_dict, inplace=True)

def df_columns_act(df,yr):
    df.columns=df.columns.str.lower().str.replace(" ","_")
    df['state']=df['state'].str.lower()
    new_column_sat_dict={'participation':"participation_rate_act_"+str(yr),
                        'composite':'composite_'+str(yr)}
    return df.rename(columns=new_column_sat_dict, inplace=True)

# %%
df_columns_sat(df_sat_2017,2017)
df_columns_sat(df_sat_2018,2018)
df_columns_sat(df_sat_2019,2019)
df_columns_act(df_act_2017,2017)
#df_act_2017.drop(columns=['english','math','reading','science'], inplace=True)
df_columns_act(df_act_2018,2018)
df_columns_act(df_act_2019,2019)

# %%
df_act_2017.head(1)
# Out:
#       state  participation_rate_act_2017  english  math  reading  science  \
# 0  national                           60     20.3  20.7     21.4     21.0
#
#    composite_2017
# 0            21.0

# %%
df_act_2018.head(1)
# Out:
#      state  participation_rate_act_2018  composite_2018
# 0  alabama                          100            19.1

# %%
df_act_2019.head(1)
# Out:
#      state  participation_rate_act_2019  composite_2019
# 0  alabama                          100            18.9

# %%
df_sat_2019.isnull().sum()
df_sat_2019.dropna(inplace=True)
df_sat_2019.shape
# Out:
# (51, 5)

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %%
print(f"This table shows the features of ACT and SAT tests")
table={
    "Feature":["state", "participation_rate", "evidence-based_reading_and_writing","math","total_score","composite"],
    "Type":["object","int64 ","int64","int64","int64","float64"],
    "Dataset":["ACT/SAT","ACT/SAT","SAT","SAT","SAT","ACT"],
    "Description":["Name of the US states","rate of the participants attended these tests",
                   "reported scores of EBRR in SAT test","reported scores of math in SAT test",
                   "reported total scores in SAT/ACT test","reported composite scores in ACT test"],
    "Possible Range":["NAN","0-100","200-800","200-800","400-1600","1-36"]
}
df=pd.DataFrame(table)
df
# Out:
# This table shows the features of ACT and SAT tests
#                               Feature     Type  Dataset  \
# 0                               state   object  ACT/SAT
# 1                  participation_rate   int64   ACT/SAT
# 2  evidence-based_reading_and_writing    int64      SAT
# 3                                math    int64      SAT
# 4                         total_score    int64      SAT
# 5                           composite  float64      ACT
#
#                                      Description Possible Range
# 0                          Name of the US states            NAN
# 1  rate of the participants attended these tests          0-100
# 2            reported scores of EBRR in SAT test        200-800
# 3            reported scores of math in SAT test        200-800
# 4          reported total scores in SAT/ACT test       400-1600
# 5          reported composite scores in ACT test           1-36

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
states_list=['alabama', 'alaska', 'arizona', 'arkansas', 'california',
       'colorado', 'connecticut', 'delaware', 'district of columbia',
       'florida', 'georgia', 'hawaii', 'idaho', 'illinois', 'indiana',
       'iowa', 'kansas', 'kentucky', 'louisiana', 'maine', 'maryland',
       'massachusetts', 'michigan', 'minnesota', 'mississippi',
       'missouri', 'montana', 'nebraska', 'nevada', 'new hampshire',
        'new jersey', 'new mexico', 'new york','north carolina',
        'north dakota', 'ohio', 'oklahoma', 'oregon', 'pennsylvania',
        'rhode island', 'south carolina', 'south dakota','tennessee',
        'texas', 'utah', 'vermont', 'virginia', 'washington',
       'west virginia', 'wisconsin', 'wyoming']
def check_list(df):
    A=["T" if list(df['state'])[_] in states_list else "F" for _ in range(0,len(list(df['state'])))]
    if "F" in A:
        return A.index("F")
    else:
        return f"There is no unusual item in the list"

# %%
check_list(df_act_2017)
df_act_2017.drop([0], inplace=True)

# %%
check_list(df_act_2019)
df_act_2019.drop([51], inplace=True)

# %%
df_act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 51
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   state                        51 non-null     object
#  1   participation_rate_act_2017  51 non-null     int64
#  2   english                      51 non-null     float64
#  3   math                         51 non-null     float64
#  4   reading                      51 non-null     float64
#  5   science                      51 non-null     float64
#  6   composite_2017               51 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.2+ KB

# %%
df_act_2018.drop_duplicates('state', inplace=True)
df_act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   state                        51 non-null     object
#  1   participation_rate_act_2018  51 non-null     int64
#  2   composite_2018               51 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.6+ KB

# %%
df_act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   state                        51 non-null     object
#  1   participation_rate_act_2019  51 non-null     int64
#  2   composite_2019               51 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.6+ KB

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
df_sat_act_2017=pd.merge(df_sat_2017,df_act_2017, how='left')
df_sat_act_2018=pd.merge(df_sat_2018,df_act_2018, how='left')
df_sat_act_2019=pd.merge(df_sat_2019,df_act_2019, how='left')

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
df_sat_act_2017.to_csv('combined_2017.csv')
df_sat_act_2018.to_csv('combined_2018.csv')
df_sat_act_2019.to_csv('combined_2019.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Read in the `sat_2018.csv` and `act_2018.csv` files and assign them to appropriately named pandas dataframes. For the **2018 ACT Data**, only the `Composite` scores are available. Repeat the same processes to clean the 2018 data here as you were instructed in the previous sections above.

# %%
df_sat_act_2017.head()
# Out:
#         state  participation_rate_sat_2017  \
# 0     alabama                            5
# 1      alaska                           38
# 2     arizona                           30
# 3    arkansas                            3
# 4  california                           53
#
#    evidence-based_reading_and_writing_2017  math_2017  total_score_2017  \
# 0                                      593        572              1165
# 1                                      547        533              1080
# 2                                      563        553              1116
# 3                                      614        594              1208
# 4                                      531        524              1055
#
#    participation_rate_act_2017  english  math  reading  science  \
# 0                          100     18.9  18.4     19.7     19.4
# 1                           65     18.7  19.8     20.4     19.9
# 2                           62     18.6  19.8     20.1     19.8
# ...

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
Pre_1=pd.merge(df_sat_act_2017,df_sat_act_2018,how='left')
final=pd.merge(Pre_1,df_sat_act_2019,how='left')
final.to_csv('final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
final.describe().T
# Out:
#                                          count         mean        std    min  \
# participation_rate_sat_2017               51.0    39.803922  35.276632    2.0
# evidence-based_reading_and_writing_2017   51.0   569.117647  45.666901  482.0
# math_2017                                 51.0   547.627451  84.909119   52.0
# total_score_2017                          51.0  1126.098039  92.494812  950.0
# participation_rate_act_2017               51.0    65.254902  32.140842    8.0
# english                                   51.0    20.931373   2.353677   16.3
# math                                      51.0    21.182353   1.981989   18.0
# reading                                   51.0    22.013725   2.067271   18.1
# science                                   51.0    21.041176   3.182463    2.3
# composite_2017                            51.0    21.519608   2.020695   17.8
# participation_rate_sat_2018               51.0    45.745098  37.314256    2.0
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
import math
def stdev(df,parameter):
    n=len(df[parameter])
    pd.to_numeric(df[parameter])
    mean=df[parameter].mean()
    stdev=math.sqrt(sum([(x-mean)**2 for x in df[parameter]])/n)
    return stdev
#stdev(list_numeric_columns,"participation_rate_act_2019")

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
list_numeric_columns=final.drop(columns=['state'])
list_numeric_columns.columns
A=[stdev(list_numeric_columns,parameter) for parameter in list_numeric_columns.columns]
B=list(list_numeric_columns.columns)
dict(zip(B, A ))
# Out:
# {'participation_rate_sat_2017': 34.92907076664508,
#  'evidence-based_reading_and_writing_2017': 45.21697020437866,
#  'math_2017': 84.07255521608297,
#  'total_score_2017': 91.58351056778743,
#  'participation_rate_act_2017': 31.824175751231806,
#  'english': 2.3304876369363363,
#  'math': 1.9624620273436781,
#  'reading': 2.0469029314842646,
#  'science': 3.151107895464408,
#  'composite_2017': 2.000786081581989,
#  'participation_rate_sat_2018': 36.946619223539415,
#  'evidence-based_reading_and_writing_2018': 47.03460978357609,
#  'math_2018': 47.30194550378352,
#  'total_score_2018': 93.22742384464433,
#  'participation_rate_act_2018': 33.70173582041031,
#  'composite_2018': 2.090779082141178,
#  'participation_rate_sat_2019': 38.365840486857266,
#  'evidence-based_reading_and_writing_2019': 45.792378682545134,
#  'math_2019': 50.78521461840036,
#  'total_score_2019': 96.24027185617864,
#  'participation_rate_act_2019': 34.17582373703048,
# ...

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer:
# Values are slighlt different by they are in a same range.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
sat_2017_max=final.loc[:,['state','participation_rate_sat_2017']].sort_values('participation_rate_sat_2017',
                                                                              ascending=False).head()
sat_2017_min=final.loc[:,['state','participation_rate_sat_2017']].sort_values('participation_rate_sat_2017',
                                                                              ascending=True).head()
act_2017_max=final.loc[:,['state','participation_rate_act_2017']].sort_values('participation_rate_act_2017',
                                                                              ascending=False).head(20)
act_2017_min=final.loc[:,['state','participation_rate_act_2017']].sort_values('participation_rate_act_2017',
                                                                              ascending=True).head()

# %%
sat_2018_max=final.loc[:,['state','participation_rate_sat_2018']].sort_values('participation_rate_sat_2018',
                                                                              ascending=False).head()
sat_2018_min=final.loc[:,['state','participation_rate_sat_2018']].sort_values('participation_rate_sat_2018',
                                                                              ascending=True).head()
act_2018_max=final.loc[:,['state','participation_rate_act_2018']].sort_values('participation_rate_act_2018',
                                                                              ascending=False).head(20)
act_2018_min=final.loc[:,['state','participation_rate_act_2018']].sort_values('participation_rate_act_2018',
                                                                              ascending=True).head()

# %%
sat_2019_max=final.loc[:,['state','participation_rate_sat_2019']].sort_values('participation_rate_sat_2019',
                                                                              ascending=False).head()
sat_2019_min=final.loc[:,['state','participation_rate_sat_2019']].sort_values('participation_rate_sat_2019',
                                                                              ascending=True).head()
act_2019_max=final.loc[:,['state','participation_rate_act_2019']].sort_values('participation_rate_act_2019',
                                                                              ascending=False).head(20)
act_2019_min=final.loc[:,['state','participation_rate_act_2019']].sort_values('participation_rate_act_2019',
                                                                              ascending=True).head()

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize=(25,25))
corr=final.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    sns.heatmap(corr, mask=mask, vmax=.3, square=True, annot=True)
plt.title("Heatmap for ACT and SAT scores collected from all US states during 2017-2019", fontsize=25, 
          color='blue',loc='center',fontweight="bold")
plt.savefig("images/Heatmap.jpg", dpi=600);

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/3)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=3, figsize=(16,9)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        ax[i].set_ylabel('Frequency',fontsize=20)
        ax[i].set_xlabel(list_of_xlabels[i],fontsize=20)
        ax[i].set_ylim(0,25)
        ax[i].set_title(list_of_titles[i])
    fig.tight_layout(pad=0.5)
        
list_of_columns=['participation_rate_sat_2017','participation_rate_sat_2018','participation_rate_sat_2019',
                'participation_rate_act_2017','participation_rate_act_2018',
                'participation_rate_act_2019']
list_of_titles=['participation_rate_sat_2017','participation_rate_sat_2018','participation_rate_sat_2019',
                'participation_rate_act_2017','participation_rate_act_2018',
                'participation_rate_act_2019']
list_of_xlabels=['Percent','Percent','Percent','Percent','Percent','Percent']
subplot_histograms(final,list_of_columns, list_of_titles, list_of_xlabels)

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
fig= plt.figure(figsize=(15,5))
ax1=plt.subplot(131)
ax1.set_title("Paraticipation rate for SAT test in 2017",fontsize=15)
ax1.hist(final['participation_rate_sat_2017'])
ax1.set_ylabel("Frequency")
ax1.set_xlabel("Percent")
ax1.set_ylim(0,22)
ax1.yaxis.set_major_locator(MultipleLocator(3))

ax2=plt.subplot(132)
ax2.set_title("Paraticipation rate for SAT test in 2018",fontsize=15)
ax2.hist(final['participation_rate_sat_2018'])
ax2.set_ylabel("Frequency")
ax2.set_xlabel("Percent")
ax2.set_ylim(0,22)
ax2.yaxis.set_major_locator(MultipleLocator(3))

ax3=plt.subplot(133)
ax3.set_title("Paraticipation rate for SAT test in 2019",fontsize=15)
ax3.hist(final['participation_rate_sat_2019'])
ax3.set_ylabel("Frequency")
ax3.set_xlabel("Percent")
ax3.set_ylim(0,22)
ax3.yaxis.set_major_locator(MultipleLocator(3))

fig.tight_layout(pad=0.5)
fig.savefig("images/Histogram_SAT_Participation_Rate.jpg", dpi=600)

# %%
fig= plt.figure(figsize=(15,5))
ax1=plt.subplot(131)
ax1.set_title("Paraticipation rate for ACT test in 2017", color='green',fontsize=15)
ax1.hist(final['participation_rate_act_2017'], color='green')
ax1.set_ylabel("Frequency")
ax1.set_xlabel("Percent")
ax1.set_ylim(0,22)
ax1.yaxis.set_major_locator(MultipleLocator(3))

ax2=plt.subplot(132)
ax2.set_title("Paraticipation rate for ACT test in 2018", color='green',fontsize=15)
ax2.hist(final['participation_rate_act_2018'], color='green')
ax2.set_ylabel("Frequency")
ax2.set_xlabel("Percent")
ax2.set_ylim(0,22)
ax2.yaxis.set_major_locator(MultipleLocator(3))

ax3=plt.subplot(133)
ax3.set_title("Paraticipation rate for ACT test in 2019", color='green',fontsize=15)
ax3.hist(final['participation_rate_act_2019'], color='green')
ax3.set_ylabel("Frequency")
ax3.set_xlabel("Percent")
ax3.set_ylim(0,22)
ax3.yaxis.set_major_locator(MultipleLocator(3))

fig.tight_layout(pad=0.5)
fig.savefig("images/Histogram_ACT_Participation_Rate.jpg", dpi=600)

# %%
fig= plt.figure(figsize=(15,5))
ax1=plt.subplot(131)
ax1.set_title("MATH score for SAT test in 2017", color='r')
ax1.hist(final['math_2017'], color='r')
ax1.set_ylabel("Frequency")
ax1.set_xlabel("Score")
ax1.set_xlim(40,660)
ax1.set_ylim(0,18)
ax1.yaxis.set_major_locator(MultipleLocator(3))
ax1.xaxis.set_major_locator(MultipleLocator(100))

ax2=plt.subplot(132)
ax2.set_title("MATH score for SAT test in 2018", color='r')
ax2.hist(final['math_2018'], color='r')
ax2.set_ylabel("Frequency")
ax2.set_xlabel("Score")
ax2.set_xlim(40,660)
ax2.set_ylim(0,18)
ax2.yaxis.set_major_locator(MultipleLocator(3))
ax2.xaxis.set_major_locator(MultipleLocator(100))

ax3=plt.subplot(133)
ax3.set_title("MATH score for SAT test in 2019", color='r')
ax3.hist(final['math_2019'], color='r')
ax3.set_ylabel("Frequency")
ax3.set_xlabel("Score")
ax3.set_xlim(40,660)
ax3.set_ylim(0,18)
ax3.yaxis.set_major_locator(MultipleLocator(3))
ax3.xaxis.set_major_locator(MultipleLocator(100))

fig.tight_layout(pad=0.5)
fig.savefig("images/Histogram_SAT_Math_1.jpg", dpi=600)

# %%
fig= plt.figure(figsize=(15,5))
ax1=plt.subplot(131)
ax1.set_title("MATH score for SAT test in 2017", color='r')
ax1.hist(final['math_2017'], color='r')
ax1.set_ylabel("Frequency")
ax1.set_xlabel("Score")
ax1.set_xlim(400,660)
ax1.set_ylim(0,18)
ax1.yaxis.set_major_locator(MultipleLocator(3))
ax1.xaxis.set_major_locator(MultipleLocator(100))

ax2=plt.subplot(132)
ax2.set_title("MATH score for SAT test in 2018", color='r')
ax2.hist(final['math_2018'], color='r')
ax2.set_ylabel("Frequency")
ax2.set_xlabel("Score")
ax2.set_xlim(400,660)
ax2.set_ylim(0,18)
ax2.yaxis.set_major_locator(MultipleLocator(3))
ax2.xaxis.set_major_locator(MultipleLocator(100))

ax3=plt.subplot(133)
ax3.set_title("MATH score for SAT test in 2019", color='r')
ax3.hist(final['math_2019'], color='r')
ax3.set_ylabel("Frequency")
ax3.set_xlabel("Score")
ax3.set_xlim(400,660)
ax3.set_ylim(0,18)
ax3.yaxis.set_major_locator(MultipleLocator(3))
ax3.xaxis.set_major_locator(MultipleLocator(100))

fig.tight_layout(pad=0.5)
fig.savefig("images/Histogram_SAT_Math_2.jpg", dpi=600)

# %%
fig= plt.figure(figsize=(10,10))
#ax1=plt.subplot(311)
plt.title("Distribution of MATH score for ACT test in 2017", color='green')
plt.hist(final['math'], color='green')
plt.ylabel("Frequency", fontsize=25)
plt.xlabel("Score", fontsize=25)
ax1.set_xlim(17,26)
ax1.set_ylim(0,10);
fig.savefig("images/Histogram_ACT_Math_2017.jpg", dpi=600)

# %%
fig= plt.figure(figsize=(15,5))
ax1=plt.subplot(131)
ax1.set_title("READING/VERBAL scores for SAT test in 2017", color='blue',fontsize=12)
ax1.hist(final['evidence-based_reading_and_writing_2017'])
ax1.set_ylabel("Frequency")
ax1.set_xlabel("Score")
ax1.set_ylim(0,12)
ax1.set_xlim(470,650)

ax2=plt.subplot(132)
ax2.set_title("READING/VERBAL scores for SAT test in 2018", color='blue',fontsize=12)
ax2.hist(final['evidence-based_reading_and_writing_2018'])
ax2.set_ylabel("Frequency")
ax2.set_xlabel("Score")
ax2.set_ylim(0,12)
ax2.set_xlim(470,650)

ax3=plt.subplot(133)
ax3.set_title("READING/VERBAL scores for SAT test in 2019", color='blue',fontsize=12)
ax3.hist(final['evidence-based_reading_and_writing_2019'])
ax3.set_ylabel("Frequency")
ax3.set_xlabel("Score")
ax3.set_ylim(0,12)
ax3.set_xlim(470,650)

fig.tight_layout(pad=0.5)
fig.savefig("images/Histogram_SAT_READING.jpg", dpi=600)

# %%
fig= plt.figure(figsize=(15,5))
ax1=plt.subplot(131)
ax1.set_title("COMPOSITE scores for ACT test in 2017", color='green',fontsize=15)
ax1.hist(final['composite_2017'], color='green')
ax1.set_ylabel("Frequency")
ax1.set_xlabel("Score")
ax1.set_ylim(0,11)
ax1.set_xlim(17.5,26)
#ax3.yaxis.set_major_locator(MultipleLocator(3))

ax2=plt.subplot(132)
ax2.set_title("COMPOSITE scores for ACT test in 2018", color='green',fontsize=15)
ax2.hist(final['composite_2018'], color='green')
ax2.set_ylabel("Frequency")
ax2.set_xlabel("Score")
ax2.set_ylim(0,11)
ax2.set_xlim(17.5,26)

ax3=plt.subplot(133)
ax3.set_title("COMPOSITE scores for ACT test in 2019", color='green',fontsize=15)
ax3.hist(final['composite_2019'], color='green')
ax3.set_ylabel("Frequency")
ax3.set_xlabel("Score")
ax3.set_ylim(0,11)
ax3.set_xlim(17.5,26)

fig.tight_layout(pad=0.5)
fig.savefig("images/Histogram_ACT_COMPOSITE.jpg", dpi=600)

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
plt.figure(figsize=(10,10))
plt.scatter(final['math'],final['math_2017'], s=300,c='r',marker='H')
plt.title("SAT vs. ACT math scores for 2017",fontweight="bold")
plt.ylabel("SAT math scores", fontsize = 30)
plt.xlabel("ACT math scores", fontsize = 30)
plt.ylim(0,700)
plt.savefig("images/Scatter_SAT_ACT math scores for 2017.jpg", dpi=600)

# %%
plt.figure(figsize=(10,10))
plt.scatter(final['math'],final['math_2017'], s=300,c='r',marker='H')
plt.title("SAT vs. ACT math scores for 2017",fontweight="bold")
plt.ylabel("SAT math scores", fontsize = 30)
plt.xlabel("ACT math scores", fontsize = 30);
plt.ylim(450,660)
plt.savefig("images/Scatter_SAT_ACT math scores for 2017_2.jpg", dpi=600);

# %%
#SAT vs. ACT verbal/reading scores for 2017
plt.figure(figsize=(10,10))
plt.scatter(final['reading'],final['evidence-based_reading_and_writing_2017'], s=300,c='green',marker='o')
plt.title("SAT vs. ACT verbal/reading scores for 2017",fontweight="bold")
plt.ylabel("SAT EBRW scores", fontsize = 30)
plt.xlabel("ACT reading scores", fontsize = 30)
plt.ylim(450,660)
plt.savefig("images/Scatter_SAT_ACT verbal scores for 2017.jpg", dpi=600);

# %%
#SAT vs. ACT total/composite scores for 2017
plt.figure(figsize=(10,10))
plt.scatter(final['composite_2017'],final['total_score_2017'], s=300,c='blue',marker='^')
plt.title("SAT vs. ACT total/composite scores for 2017",fontweight="bold")
plt.ylabel("SAT total scores", fontsize = 30)
plt.xlabel("ACT composite scores", fontsize = 30)
plt.savefig("images/Scatter_SAT_ACT total scores for 2017.jpg", dpi=600);

# %%
#Total scores for SAT 2017 vs. 2018
plt.figure(figsize=(10,10))
plt.scatter(final['total_score_2018'],final['total_score_2017'], s=300,c='black',marker='p')
plt.title("Total scores for SAT 2017 vs. SAT 2018",fontweight="bold")
plt.ylabel("SAT total scores (2017)", fontsize = 30)
plt.xlabel("SAT total scores (2018)", fontsize = 30)
plt.xlim(900,1400)
plt.ylim(900,1400)
plt.savefig("images/Scatter_SAT_SAT total scores for 2017-2018.jpg", dpi=600);

# %%
#Total scores for SAT 2017 vs. 2019
plt.figure(figsize=(10,10))
plt.scatter(final['total_score_2019'],final['total_score_2017'], s=300,c='black',marker='p')
plt.title("Total scores for SAT 2017 vs. SAT 2019",fontweight="bold")
plt.ylabel("SAT total scores (2017)", fontsize = 30)
plt.xlabel("SAT total scores (2019)", fontsize = 30)
plt.xlim(900,1400)
plt.ylim(900,1400)
plt.savefig("images/Scatter_SAT_SAT total scores for 2017-2019.jpg", dpi=600);

# %%
#Total scores for SAT 2018 vs. 2019
plt.figure(figsize=(10,10))
plt.scatter(final['total_score_2019'],final['total_score_2018'], s=300,c='black',marker='p')
plt.title("Total scores for SAT 2018 vs. SAT 2019",fontweight="bold")
plt.ylabel("SAT total scores (2018)", fontsize = 30)
plt.xlabel("SAT total scores (2019)", fontsize = 30)
plt.xlim(900,1400)
plt.ylim(900,1400)
plt.savefig("images/Scatter_SAT_SAT total scores for 2018-2019.jpg", dpi=600);

# %%
#Composite scores for ACT 2017 vs. 2018
plt.figure(figsize=(10,10))
plt.scatter(final['composite_2018'],final['composite_2017'], s=300,c='black',marker='D')
plt.title("Composite scores for ACT 2017 vs. ACT 2018",fontweight="bold")
plt.ylabel("ACT composite scores (2017)", fontsize = 30)
plt.xlabel("ACT composite scores (2018)", fontsize = 30)
plt.xlim(17,26)
plt.ylim(17,26)
plt.savefig("images/Scatter_ACT_ACT Composite scores for 2017-2018.jpg", dpi=600);

# %%
#Composite scores for ACT 2017 vs. 2019
plt.figure(figsize=(10,10))
plt.scatter(final['composite_2019'],final['composite_2017'], s=300,c='black',marker='D')
plt.title("Composite scores for ACT 2017 vs. ACT 2019",fontweight="bold")
plt.ylabel("ACT composite scores (2017)", fontsize = 30)
plt.xlabel("ACT composite scores (2019)", fontsize = 30)
plt.xlim(17,26)
plt.ylim(17,26)
plt.savefig("images/Scatter_ACT_ACT Composite scores for 2017-2019.jpg", dpi=600);

# %%
#Composite scores for ACT 2018 vs. 2019
plt.figure(figsize=(10,10))
plt.scatter(final['composite_2019'],final['composite_2018'], s=300,c='black',marker='D')
plt.title("Composite scores for ACT 2018 vs. ACT 2019",fontweight="bold")
plt.ylabel("ACT composite scores (2018)", fontsize = 30)
plt.xlabel("ACT composite scores (2019)", fontsize = 30)
plt.xlim(17,26)
plt.ylim(17,26)
plt.savefig("images/Scatter_ACT_ACT Composite scores for 2018-2019.jpg", dpi=600);

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
ax=sns.boxplot(data=final, order=['composite_2017','composite_2018','composite_2019'],orient='h',linewidth=2.5, saturation=1);
ax.set_title("Composite section in ACT test during 2017-2019",loc="right");
ax.set_ylabel("ACT test",fontsize=25)
ax.set_xlabel("Score",fontsize=25);
plt.savefig("images/Boxplot_ACT_Composite scores.jpg", dpi=600);

# %%
ax=sns.boxplot(data=final, order=['participation_rate_sat_2017','participation_rate_sat_2018',
                               'participation_rate_sat_2019'],orient='h',linewidth=2.5, saturation=1);
ax.set_title("Participation rate in SAT test during 2017-2019",loc='right');
ax.set_ylabel("SAT test",fontsize=25)
ax.set_xlabel("Score",fontsize=25)
plt.savefig("images/Boxplot_SAT_Participation_rate.jpg", dpi=600);

# %%
ax=sns.boxplot(data=final, order=['participation_rate_act_2017','participation_rate_act_2018',
                               'participation_rate_act_2019'],orient='h',linewidth=2.5, saturation=1);
ax.set_title("Participation rate section in ACT test during 2017-2019",loc='right');
ax.set_ylabel("ACT test",fontsize=25)
ax.set_xlabel("Score",fontsize=25)
plt.savefig("images/Boxplot_ACT_Participation_rate.jpg", dpi=600);

# %%
ax=sns.boxplot(data=final, order=['evidence-based_reading_and_writing_2017','evidence-based_reading_and_writing_2018',
                               'evidence-based_reading_and_writing_2019'],orient='h',linewidth=2.5, saturation=1,
                               palette="flare");
ax.set_title("EBRW section in SAT tests during 2017-2019",loc='right');
ax.set_ylabel("SAT test",fontsize=25)
ax.set_xlabel("Score",fontsize=25)
plt.savefig("images/Boxplot_SAT_EBRW.jpg", dpi=600);

# %%
ax=sns.boxplot(data=final, order=['math_2017','math_2018','math_2019'],orient='h',linewidth=2.5, saturation=1,
                               palette="flare");
ax.set_title("Math section in SAT tests during 2017-2019",loc='right');
ax.set_ylabel("SAT test",fontsize=25)
ax.set_xlabel("Score",fontsize=25)
plt.savefig("images/Boxplot_SAT_Math.jpg", dpi=600);

# %%
ax=sns.boxplot(data=final, order=['total_score_2017','total_score_2018','total_score_2019'],orient='h',linewidth=2.5, saturation=1,
                               palette="flare");
ax.set_title("Total scores in SAT test during 2017-2019",loc='right');
ax.set_ylabel("SAT test", fontsize=25)
ax.set_xlabel("Score", fontsize=25)
plt.savefig("images/Boxplot_SAT_Total.jpg", dpi=600);

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %%
final_plus_SAT=final[['state','participation_rate_sat_2017','participation_rate_sat_2018','participation_rate_sat_2019']]
final_plus_SAT[(final_plus_SAT['participation_rate_sat_2017']==final_plus_SAT['participation_rate_sat_2018']) &
                  (final_plus_SAT['participation_rate_sat_2018']==final_plus_SAT['participation_rate_sat_2019'])]
# Out:
#            state  participation_rate_sat_2017  participation_rate_sat_2018  \
# 6    connecticut                          100                          100
# 7       delaware                          100                          100
# 16        kansas                            4                            4
# 17      kentucky                            4                            4
# 22      michigan                          100                          100
# 27      nebraska                            3                            3
# 34  north dakota                            2                            2
# 41  south dakota                            3                            3
# 49     wisconsin                            3                            3
# 50       wyoming                            3                            3
#
#     participation_rate_sat_2019
# 6                         100.0
# 7                         100.0
# 16                          4.0
# ...

# %%
final_plus_SAT[(final_plus_SAT['participation_rate_sat_2017']>final_plus_SAT['participation_rate_sat_2018']) &
                  (final_plus_SAT['participation_rate_sat_2018']>final_plus_SAT['participation_rate_sat_2019'])]
# Out:
#      state  participation_rate_sat_2017  participation_rate_sat_2018  \
# 28  nevada                           26                           23
#
#     participation_rate_sat_2019
# 28                         20.0

# %%
final_plus_SAT[(final_plus_SAT['participation_rate_sat_2017']<final_plus_SAT['participation_rate_sat_2018']) &
                  (final_plus_SAT['participation_rate_sat_2018']<final_plus_SAT['participation_rate_sat_2019'])]
# Out:
#              state  participation_rate_sat_2017  participation_rate_sat_2018  \
# 0          alabama                            5                            6
# 3         arkansas                            3                            5
# 4       california                           53                           60
# 10         georgia                           61                           70
# 13        illinois                            9                           99
# 20        maryland                           69                           76
# 21   massachusetts                           76                           80
# 31      new mexico                           11                           16
# 35            ohio                           12                           18
# 36        oklahoma                            7                            8
# 37          oregon                           43                           48
# ...

# %%
final_plus_ACT=final[['state','participation_rate_act_2017','participation_rate_act_2018','participation_rate_act_2019']]
final_plus_ACT[(final_plus_ACT['participation_rate_act_2017']==final_plus_ACT['participation_rate_act_2018']) &
                  (final_plus_ACT['participation_rate_act_2018']==final_plus_ACT['participation_rate_act_2019'])]
# Out:
#                    state  participation_rate_act_2017  \
# 0                alabama                          100
# 3               arkansas                          100
# 8   district of columbia                           32
# 17              kentucky                          100
# 18             louisiana                          100
# 24           mississippi                          100
# 26               montana                          100
# 28                nevada                          100
# 33        north carolina                          100
# 36              oklahoma                          100
# 42             tennessee                          100
# 44                  utah                          100
# 49             wisconsin                          100
# 50               wyoming                          100
#
#     participation_rate_act_2018  participation_rate_act_2019
# 0                           100                          100
# ...

# %%
final_plus_ACT[(final_plus_ACT['participation_rate_act_2017']>final_plus_ACT['participation_rate_act_2018']) &
                  (final_plus_ACT['participation_rate_act_2018']>final_plus_ACT['participation_rate_act_2019'])]
# Out:
#             state  participation_rate_act_2017  participation_rate_act_2018  \
# 4      california                           31                           27
# 5        colorado                          100                           30
# 6     connecticut                           31                           26
# 7        delaware                           18                           17
# 9         florida                           73                           66
# 10        georgia                           55                           53
# 11         hawaii                           90                           89
# 12          idaho                           38                           36
# 13       illinois                           93                           43
# 14        indiana                           35                           32
# 19          maine                            8                            7
# ...

# %%
final_plus_ACT[(final_plus_ACT['participation_rate_act_2017']<final_plus_ACT['participation_rate_act_2018']) &
                  (final_plus_ACT['participation_rate_act_2018']<final_plus_ACT['participation_rate_act_2019'])]
# Out:
#      state  participation_rate_act_2017  participation_rate_act_2018  \
# 2  arizona                           62                           66
#
#    participation_rate_act_2019
# 2                           73

# %%
final.loc[final['state']=='north dakota',['total_score_2017','total_score_2018','total_score_2019']]
# Out:
#     total_score_2017  total_score_2018  total_score_2019
# 34              1256              1283              1263

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?
#
# North Dakota shows the lowest participant rate (2%) among all states in SAT test.
#
# ACT and SAT participation distribution are inversely correlated with each other (Pearson correlation= (-0.8)-(-0.9)).
#
# participant rate is inversely correlated with SAT and ACT total scores (SAT: 2017:-0.87,2018:-0.79, 2019:-0.86, ACT: 2017:-0.86,2018:-0.86,2019:-0.87).
#
# It seems coastal states prefer to take SAT while Midwestern states prefer to take ACT.
